# %% [markdown]
# # CoChem Stage 0.0 — Unified Initialization Notebook
# This notebook executes the multi-phase setup sequence to configure the local hypervisor, map hardware resources, provision isolated Python silos, and generate the authoritative `cochem_system_config.json` registry.

# %%
# Cell 1: Master Orchestration Trigger
# !python setup.py

# %%
# Cell 2: Verify Authoritative Registry
import json
import os

if os.path.exists("cochem_system_config.json"):
    with open("cochem_system_config.json", "r") as f:
        config = json.load(f)
    print("Successfully loaded cochem_system_config.json!")
    print(json.dumps(config, indent=2))
else:
    print("⚠️ Warning: cochem_system_config.json not found. Run Cell 1 first.")
